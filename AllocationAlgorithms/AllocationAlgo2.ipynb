# %% [markdown]
# # Allocation Algorithm 2
#
# > **1.** For each child in list, assign the EI that lives closest to them
#
# > **2.** Update MySQL table locationdataalgo2
#
# > **3.** Note: There is a cap at 17 children per EI to even the distribution of children somewhat

# %%
import pandas as pd
import numpy as np
import mysql.connector

# %%
connection = mysql.connector.connect(
            host = "localhost",
            port = 3306,
            user = 'root',
            database = "expandinghorizons",
            password = "dB79@dG2024!"
)
    
cursor = connection.cursor()

# %%
query = ("UPDATE child "
         "SET assigned = 0")
cursor.execute(query)

# %%
query = ("SELECT child_id from child")
cursor.execute(query)

child_ids = cursor.fetchall()

for row in child_ids:
    print(row[0])
# Out:
# 65d76430e09e67e025e8cd43
# 65d764dde09e67e025e8cd44
# 65d766f6e09e67e025e8cd45
# 65d76799e09e67e025e8cd46
# 65d76829e09e67e025e8cd47
# 65d76956e09e67e025e8cd48
# 65d769fde09e67e025e8cd49
# 65d76b1ee09e67e025e8cd4a
# 65d76bb7e09e67e025e8cd4b
# 65d76c25e09e67e025e8cd4c
# 65d76ca3e09e67e025e8cd4d
# 65d76d38e09e67e025e8cd4e
# 65d76dcae09e67e025e8cd4f
# 65d76e6de09e67e025e8cd50
# 65d76f01e09e67e025e8cd51
# 65d76f7ae09e67e025e8cd52
# 65d76ff5e09e67e025e8cd53
# 65d77069e09e67e025e8cd54
# 65d770fde09e67e025e8cd55
# 65d771a3e09e67e025e8cd5a
# 65d7725be09e67e025e8cd5b
# 65d772ffe09e67e025e8cd5c
# 65d773a1e09e67e025e8cd5d
# 65d77c78e09e67e025e8cd5e
# 65d77d33e09e67e025e8cd5f
# 65d77ed6e09e67e025e8cd60
# 65d77f4de09e67e025e8cd61
# 65d77fdce09e67e025e8cd62
# 65d78068e09e67e025e8cd63
# 65d780cee09e67e025e8cd64
# 65d78173e09e67e025e8cd65
# 65d78213e09e67e025e8cd66
# 65d782a0e09e67e025e8cd67
# 65d7830de09e67e025e8cd68
# 65d78390e09e67e025e8cd69
# 65d7842ee09e67e025e8cd6a
# 65d78493e09e67e025e8cd6b
# 65d7852de09e67e025e8cd6c
# 65d785dee09e67e025e8cd6d
# 65d7864fe09e67e025e8cd6e
# 65d786e0e09e67e025e8cd6f
# 65d78775e09e67e025e8cd70
# 65d787f5e09e67e025e8cd71
# 65d7886ae09e67e025e8cd72
# 65d788d6e09e67e025e8cd73
# 65d89f0de09e67e025e8cd74
# 65d8b217e09e67e025e8cd75
# 65d8b2bce09e67e025e8cd76
# 65d8b327e09e67e025e8cd77
# 65d8b3f9e09e67e025e8cd78
# 65d8b4e2e09e67e025e8cd79
# 65d8b5cae09e67e025e8cd7a
# 65d8b679e09e67e025e8cd7b
# 65d8b6f8e09e67e025e8cd7c
# 65d8b770e09e67e025e8cd7d
# 65d8b7d1e09e67e025e8cd7e
             "order by driving_distance asc")
    cursor.execute(query)
    child_data = cursor.fetchall()
    
    if child_data:
        for child in child_data:
            ei = child[1]
            longitude = child[5]
            latitude = child[6]
            alloCount = child[8]
            break
        alloCount += 1

        updateQuery = ("UPDATE locationdataalgo2 ld "
                       "JOIN child on ld.child_id_1 = child.child_id "
                       "JOIN ei on ei.ei_id = ld.ei_id_1 "
                       f"SET ld.assigned = 1, child.assigned = 1, ei.Allo_Count = {alloCount} " 
                       f"WHERE child.longitude = {longitude} and child.latitude = {latitude} and ld.ei_id_1 = '{ei}'")
        cursor.execute(updateQuery)
        connection.commit()
        print("Update query pushed")
    else:
        query = ("Select ld.child_id_1, ld.ei_id_1, ld.assigned, ld.driving_distance, ld.driving_time, child.Longitude, child.Latitude, child.assigned from locationdataalgo2 ld "
                 "join child on child.child_id=ld.child_id_1 "
                 f"where ld.child_id_2 is null and ld.ei_id_2 is null and child.assigned = 1 and ld.child_id_1 = '{child[0]}' "
                 "order by driving_distance asc")
        cursor.execute(query)
        data = cursor.fetchall()
        
        if data:
            print(f"{child[0]} already assigned")
        else:
            print("Error")
# Out:
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65d78068e09e67e025e8cd63 already assigned
# Update query pushed
# 65d78173e09e67e025e8cd65 already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65d78493e09e67e025e8cd6b already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65d7886ae09e67e025e8cd72 already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65d8b6f8e09e67e025e8cd7c already assigned
# Update query pushed
# 65d8b7d1e09e67e025e8cd7e already assigned
# Update query pushed
# 65d8b8b7e09e67e025e8cd80 already assigned
# Update query pushed
# 65d8b9c0e09e67e025e8cd82 already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65d8be2ae09e67e025e8cd8a already assigned
# Update query pushed
# 65d8bf9ce09e67e025e8cd8c already assigned
# 65d8c01ee09e67e025e8cd8d already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65d8d7c4e09e67e025e8cdb7 already assigned
# Update query pushed
# Update query pushed
# 65d8d8fee09e67e025e8cdba already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65e5cc7f38f826f292671fee already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65e5d23538f826f292671ff7 already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65e5d57838f826f292671ffd already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65e5d8f938f826f292672005 already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65e5e3c238f826f29267201c already assigned
# Update query pushed
# 65e5e60a38f826f29267201e already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# 65e5fe7438f826f292672025 already assigned
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed
# Update query pushed

# %%
query = ("SELECT ei_id FROM ei ")
cursor.execute(query)

ei_ids = cursor.fetchall()

for row in ei_ids:
    print(row[0])
# Out:
# 65d75a2ce09e67e025e8cd30
# 65d75bb0e09e67e025e8cd31
# 65d75c59e09e67e025e8cd32
# 65d75c87e09e67e025e8cd33
# 65d75cb9e09e67e025e8cd34
# 65d75ce1e09e67e025e8cd35
# 65d75d08e09e67e025e8cd36
# 65d75d4ce09e67e025e8cd37
# 65d75d80e09e67e025e8cd38
# 65d75da9e09e67e025e8cd39
# 65d75dd5e09e67e025e8cd3a
# 65d75dfae09e67e025e8cd3b
# 65d75e28e09e67e025e8cd3c
