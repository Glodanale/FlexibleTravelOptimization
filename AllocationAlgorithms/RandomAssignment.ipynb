# %% [markdown]
# # Random Assignment
#
# > **1.** Pull all children from database
#
# > **2.** Pull list of EIs from database
#
# > **3.** Shuffle rows in dataframe of children
#
# > **4.** Go through the list of children assigning an EI to them sequentially from list of EIs
#
# > **5.** Update MySQL table locationdatarandom

# %%
import pandas as pd
import numpy as np
import mysql.connector

# %%
def pullDataFromMySQL():
    connection = mysql.connector.connect(
            host = "localhost",
            port = 3306,
            user = 'root',
            database = "expandinghorizons",
            password = "dB79@dG2024!"
    )
    
    cursor = connection.cursor()
    
    query = ("SELECT * FROM locationdatarandom "
             "Where child_id_2 is null and ei_id_2 is null")
    cursor.execute(query)
    
    rows = cursor.fetchall()
    
    column_names = ['pair_id', 'child_id_1', 'child_id_2', 'ei_id_1', 'ei_id_2', 'assigned', 'driving_distance', 'driving_time']

    # Create DataFrame
    data = pd.DataFrame(rows, columns=column_names)
    
    print(data)
    
    cursor.close()
    connection.close()
    
    return data

# %%
def pullChildrenFromMySQL():
    connection = mysql.connector.connect(
            host = "localhost",
            port = 3306,
            user = 'root',
            database = "expandinghorizons",
            password = "dB79@dG2024!"
    )
    
    cursor = connection.cursor()
    
    query = ("SELECT child_id, First_Name, Last_Name FROM child ")
    cursor.execute(query)
    
    rows = cursor.fetchall()
    
    column_names = ['child_id', 'First_Name', 'Last_Name']

    # Create DataFrame
    data = pd.DataFrame(rows, columns=column_names)
    
    print(data)
    
    cursor.close()
    connection.close()
    
    return data

# %%
def pullEIFromMySQL():
    connection = mysql.connector.connect(
            host = "localhost",
            port = 3306,
            user = 'root',
            database = "expandinghorizons",
            password = "dB79@dG2024!"
    )
    
    cursor = connection.cursor()
    
    query = ("SELECT ei_id, First_Name, Last_Name FROM ei "
             "WHERE ei_id != '65d75e28e09e67e025e8cd3c'")
    cursor.execute(query)
    
    rows = cursor.fetchall()
    
    column_names = ['ei_id', 'First_Name', 'Last_Name']

    # Create DataFrame
    data = pd.DataFrame(rows, columns=column_names)
    
    print(data)
    
    cursor.close()
    connection.close()
    
    return data

# %%
child = pullChildrenFromMySQL()
shuffled_children = child.sample(frac=1)
shuffled_children.reset_index(drop=True, inplace=True)
shuffled_children["Assigned_EI"] = ""
print(shuffled_children)
# Out:
#                      child_id First_Name   Last_Name
# 0    65d76430e09e67e025e8cd43       John      Fauver
# 1    65d764dde09e67e025e8cd44      River     Hefflin
# 2    65d766f6e09e67e025e8cd45        Kai  Khaysavang
# 3    65d76799e09e67e025e8cd46     Robert      Richie
# 4    65d76829e09e67e025e8cd47    Matilda     Withrow
# ..                        ...        ...         ...
# 191  65e6038938f826f29267202f      Judah     Overbay
# 192  65e603f238f826f292672030     Bianca       Pogue
# 193  65e6044938f826f292672031    Emorett     Woodall
# 194  65e6049b38f826f292672032       Remi       Woody
# 195  65ef076606e0a866af56d202   Madilynn      Phipps
#
# [196 rows x 3 columns]
#                      child_id First_Name Last_Name Assigned_EI
# 0    65e6027b38f826f29267202d     Finlay    Monroe
# 1    65e5df8638f826f292672014      Dante      Rhea
# 2    65d8d17be09e67e025e8cdab     Zayden    Bishop
# 3    65e5ff9838f826f292672027     Damien     Hicks
# 4    65e5cdba38f826f292671ff0       Aray    Wilson
# ..                        ...        ...       ...         ...
# 191  65d8b7d1e09e67e025e8cd7e     Corbin     Kimes
# 192  65e5d6b638f826f292672000   Izabella   Leonard
# 193  65d8c331e09e67e025e8cd93     Oaklen   Russell
# 194  65d8d4b3e09e67e025e8cdb1      Lyric    Lawson
# 195  65d8d1dae09e67e025e8cdac     Elijah   Chaffee
#
# [196 rows x 4 columns]

# %%
ei = pullEIFromMySQL()
# Out:
#                        ei_id First_Name   Last_Name
# 0   65d75a2ce09e67e025e8cd30       Mary  Richardson
# 1   65d75bb0e09e67e025e8cd31    Kirstin      Tipton
# 2   65d75c59e09e67e025e8cd32      Kassi      Knight
# 3   65d75c87e09e67e025e8cd33     Rachel      Taylor
# 4   65d75cb9e09e67e025e8cd34    Brannan     Vanover
# 5   65d75ce1e09e67e025e8cd35     Briana     Ailshie
# 6   65d75d08e09e67e025e8cd36       Dawn     Martino
# 7   65d75d4ce09e67e025e8cd37      Casey      Crumly
# 8   65d75d80e09e67e025e8cd38        Kim      Risner
# 9   65d75da9e09e67e025e8cd39      Lydia        Ugwu
# 10  65d75dd5e09e67e025e8cd3a      Emily    Jennings
# 11  65d75dfae09e67e025e8cd3b      Faith       Ihrig

# %%
for index, row in shuffled_children.iterrows():
    value = index % 12
    ei_value = ei.iloc[value, 0]
    row['Assigned_EI'] = ei_value
    
print(shuffled_children)
# Out:
#                      child_id First_Name Last_Name               Assigned_EI
# 0    65e6027b38f826f29267202d     Finlay    Monroe  65d75a2ce09e67e025e8cd30
# 1    65e5df8638f826f292672014      Dante      Rhea  65d75bb0e09e67e025e8cd31
# 2    65d8d17be09e67e025e8cdab     Zayden    Bishop  65d75c59e09e67e025e8cd32
# 3    65e5ff9838f826f292672027     Damien     Hicks  65d75c87e09e67e025e8cd33
# 4    65e5cdba38f826f292671ff0       Aray    Wilson  65d75cb9e09e67e025e8cd34
# ..                        ...        ...       ...                       ...
# 191  65d8b7d1e09e67e025e8cd7e     Corbin     Kimes  65d75dfae09e67e025e8cd3b
# 192  65e5d6b638f826f292672000   Izabella   Leonard  65d75a2ce09e67e025e8cd30
# 193  65d8c331e09e67e025e8cd93     Oaklen   Russell  65d75bb0e09e67e025e8cd31
# 194  65d8d4b3e09e67e025e8cdb1      Lyric    Lawson  65d75c59e09e67e025e8cd32
# 195  65d8d1dae09e67e025e8cdac     Elijah   Chaffee  65d75c87e09e67e025e8cd33
#
# [196 rows x 4 columns]

# %%
def pushToMySQL(shuffled_children):
    connection = mysql.connector.connect(
            host = "localhost",
            port = 3306,
            user = 'root',
            database = "expandinghorizons",
            password = "dB79@dG2024!"
    )
    
    cursor = connection.cursor()
    
    for index, row in shuffled_children.iterrows():
        child_id = row["child_id"]
        ei_id = row["Assigned_EI"]
        updateQuery = ("UPDATE locationdatarandom " 
                       f"SET assigned = 1 " 
                       f"WHERE child_id_1 = '{child_id}' and ei_id_1 = '{ei_id}'")
        cursor.execute(updateQuery)
        print(f"{row['First_Name']} {row['Last_Name']} updated assignement")
        connection.commit()
    
    cursor.close()
    connection.close()
    print("\n\n")
    print("End of function")

# %%
pushToMySQL(shuffled_children)
# Out:
# Finlay Monroe updated assignement
# Dante Rhea updated assignement
# Zayden Bishop updated assignement
# Damien Hicks updated assignement
# Aray Wilson updated assignement
# Dominic Knight updated assignement
# Paisley Stewart updated assignement
# Carter Sanchez updated assignement
# Gynisis Blair updated assignement
# Olivia Jones updated assignement
# Gage Butler updated assignement
# Kooper Ratliff updated assignement
# Leon Conner updated assignement
# Veronica Michels updated assignement
# Robert Richie updated assignement
# Paul Looney updated assignement
# Ezra Moretz updated assignement
# Kai Khaysavang updated assignement
# Weston Flemming updated assignement
# Claire Bail updated assignement
# Langdon Richards updated assignement
# Lennon Percell updated assignement
# Emily Curtis updated assignement
# Savannah Wade updated assignement
# Benjamin Keasling updated assignement
# Remi Woody updated assignement
# Aurora Brown updated assignement
# Colton Hanczyk updated assignement
# Zayn Still updated assignement
# Charlie Mullins updated assignement
# River Hefflin updated assignement
# Judah Overbay updated assignement
# Bodi Shuler updated assignement
# Violet Williams updated assignement
# Ivy Washer updated assignement
# Kaysus Price updated assignement
# Wyatt Trantham updated assignement
# Yssa Tiangco updated assignement
# Henrik Alexander updated assignement
# Rhylee Owens updated assignement
# Elenore Mullins updated assignement
# Simon Lane updated assignement
# Warren Bennet updated assignement
# Armani Arp updated assignement
# Mason Ketron updated assignement
# Anjell Kochan updated assignement
# Hazleigh Steadman updated assignement
# Isabella Craig updated assignement
# Paisley Carpenter updated assignement
# Cole Wallace updated assignement
# Jaxson Hinkle updated assignement
# Michael Simerly updated assignement
# Gracie Jones updated assignement
# Flynn Burt updated assignement
# Felix Grizzle updated assignement
# Aria McClellan updated assignement
# Emersyn Jones updated assignement
# Isabella Shelton updated assignement
# Adeline Dahl updated assignement
# Rowin Hall updated assignement
# Soren Anderson updated assignement
# Tianna Bernard updated assignement
# Tristan Hall updated assignement
# Avery Murray updated assignement
# Christopher Kimes updated assignement
# Leo Clay updated assignement
# Bianca Pogue updated assignement
# Rozzlyn Miller updated assignement
# Olivia Wiginton updated assignement
# Don Olomofe updated assignement
# Jameson Colyer updated assignement
# Matilda Withrow updated assignement
# Noah Mickles updated assignement
# Tristan Tetrick updated assignement
# Gwendolyn Hayes updated assignement
# Lucas Hayes updated assignement
# Corbin Helbert updated assignement
# Phoenix Taylor updated assignement
# Lincoln Fleenor updated assignement
# Aurora McClellan updated assignement
# Samantha Sams updated assignement
# Frankie Sheppard  updated assignement
# Gracelyn Hightower updated assignement
# Zenaida Gorsline updated assignement
# Malikai Howard updated assignement
# Moira McNeal updated assignement
# Michael Hicks updated assignement
# Dante Gonzalez updated assignement
# Asher Houston updated assignement
# Ezra Boss updated assignement
# Ian Hutton updated assignement
# Tucker Brooks updated assignement
# Beau Walker updated assignement
# Theodore Leroux updated assignement
# Annalyn Strouth updated assignement
# Tinsley Robinette updated assignement
# Granger Reaves updated assignement
# Roman Humphrey updated assignement
# Thomas Greff updated assignement
# Freyja Taylor updated assignement
# Wesley Greenway updated assignement
# Hazel Vandergriff updated assignement
# Cleo Whitson updated assignement
# Berkley Green updated assignement
# Lennon McCrary updated assignement
# Oaklynn Crum updated assignement
# Dansby Patrick updated assignement
# Liam Campbell updated assignement
# Elliott Ivey updated assignement
# Levi Potter updated assignement
# Cole Fields updated assignement
# Gabriella Stanley updated assignement
# Emerson Thacker updated assignement
# Raiden Holt updated assignement
# Lincoln Gilbert updated assignement
# Banks Shuler updated assignement
# Ada-Anne Dixon updated assignement
# Ellie Mullins updated assignement
# Olivia Hedrick updated assignement
# Serenity Ellis updated assignement
# Cameron Hanczyk updated assignement
# Mara Cerone updated assignement
# Sylvia Christian updated assignement
# Dixie Jones updated assignement
# Lachlan Beach updated assignement
# Jaxon Lane updated assignement
# Jericho Baxter updated assignement
# Luke Morton updated assignement
# Caden Hensley updated assignement
# Amika Burleson updated assignement
# Jackson NeSmith updated assignement
# Loc Pressinell updated assignement
# Henley Cox updated assignement
# Kade Fulwiler updated assignement
# Kylan Anderson updated assignement
# Emorett Woodall updated assignement
# Charlotte Henegar updated assignement
# Emerson Thacker updated assignement
# Adeline Fontenot updated assignement
# Cannon Lawson updated assignement
# Axel Allen updated assignement
# Jackson McKinnis updated assignement
# Henry Keasling updated assignement
# Carson Fields updated assignement
# Kirsten Hall updated assignement
# Raelynn Buckles  updated assignement
# Ledger Green updated assignement
# Storm Harshbarger updated assignement
# Ashleigh Markland updated assignement
# Isaac Williams updated assignement
# Kylie Wilson updated assignement
# Sage Irwin updated assignement
# River Schrayer updated assignement
# Romere Price updated assignement
# Paisley Tranthum updated assignement
# Easton Mayton updated assignement
# Waylon Widener updated assignement
# Ryder Carpenter updated assignement
# Bryson Hyson-Tate updated assignement
# Madilynn Phipps updated assignement
# Malachi Berry updated assignement
# Arabella Phillips updated assignement
# Solomon Manis updated assignement
# Mia Rush updated assignement
# Lakelynn Bennett updated assignement
# Ruby Birchfield updated assignement
# McKinley Boggs updated assignement
# William Thomason updated assignement
# Levi Fleenor updated assignement
# Simon Schroeder updated assignement
# Violet Stubblefield updated assignement
# Avery Lane updated assignement
# John Fauver updated assignement
# David Edwards updated assignement
# Ian Estes updated assignement
# Callum Kennedy updated assignement
# Roman Cotterman updated assignement
# Larson Ketron updated assignement
# Athena Young updated assignement
# Jayceon Green updated assignement
# Ryder Hall updated assignement
# Hunter Morton updated assignement
# Sutton Condra updated assignement
# Dallas Bell updated assignement
# Barry Williams updated assignement
# Oaklynn Trivett updated assignement
# Silas Morris updated assignement
# Marcella Mathes updated assignement
# Evelyn Jacobs updated assignement
# Willow Taylor updated assignement
# Layton Cotterman updated assignement
# Corbin Kimes updated assignement
# Izabella Leonard updated assignement
# Oaklen Russell updated assignement
# Lyric Lawson updated assignement
# Elijah Chaffee updated assignement
#
#
#
# End of function
